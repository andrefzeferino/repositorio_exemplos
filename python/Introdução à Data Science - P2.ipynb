# %%
import pandas as pd

# %%
tmdb = pd.read_csv('tmdb_5000_movies.csv', sep=',')

# %%
tmdb.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
tmdb.columns
# Out:
# Index(['budget', 'genres', 'homepage', 'id', 'keywords', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'vote_average',
#        'vote_count'],
#       dtype='object')

# %%
tmdb.original_language.unique()
# Out:
# array(['en', 'ja', 'fr', 'zh', 'es', 'de', 'hi', 'ru', 'ko', 'te', 'cn',
#        'it', 'nl', 'ta', 'sv', 'th', 'da', 'xx', 'hu', 'cs', 'pt', 'is',
#        'tr', 'nb', 'af', 'pl', 'he', 'ar', 'vi', 'ky', 'id', 'ro', 'fa',
#        'no', 'sl', 'ps', 'el'], dtype=object)

# %%
tmdb.vote_average.unique()
# Out:
# array([ 7.2,  6.9,  6.3,  7.6,  6.1,  5.9,  7.4,  7.3,  5.7,  5.4,  7. ,
#         6.5,  6.4,  6.2,  7.1,  5.8,  6.6,  7.5,  5.5,  6.7,  6.8,  6. ,
#         5.1,  7.8,  5.6,  5.2,  8.2,  7.7,  5.3,  8. ,  4.8,  4.9,  7.9,
#         8.1,  4.7,  5. ,  4.2,  4.4,  4.1,  3.7,  3.6,  3. ,  3.9,  4.3,
#         4.5,  3.4,  4.6,  8.3,  3.5,  4. ,  2.3,  3.2,  0. ,  3.8,  2.9,
#         8.5,  1.9,  3.1,  3.3,  2.2,  0.5,  9.3,  8.4,  2.7, 10. ,  1. ,
#         2. ,  2.8,  9.5,  2.6,  2.4])

# %%
tmdb.original_language.value_counts()
# Out:
# en    4505
# fr      70
# es      32
# zh      27
# de      27
# hi      19
# ja      16
# it      14
# cn      12
# ru      11
# ko      11
# pt       9
# da       7
# sv       5
# nl       4
# fa       4
# th       3
# he       3
# ta       2
# cs       2
# ro       2
# id       2
# ar       2
# vi       1
# sl       1
# ps       1
# no       1
# ky       1
# hu       1
# pl       1
# af       1
# nb       1
# tr       1
# is       1
# xx       1
# te       1
# el       1
# Name: original_language, dtype: int64

# %%
tmdb.original_language.value_counts().to_frame() #criar um dataframe a partir de um índice
# Out:
#     original_language
# en               4505
# fr                 70
# es                 32
# zh                 27
# de                 27
# hi                 19
# ja                 16
# it                 14
# cn                 12
# ru                 11
# ko                 11
# pt                  9
# da                  7
# sv                  5
# nl                  4
# fa                  4
# th                  3
# he                  3
# ta                  2
# cs                  2
# ro                  2
# id                  2
# ar                  2
# vi                  1
# sl                  1
# ps                  1
# no                  1
# ky                  1
# hu                  1
# pl                  1
# af                  1
# nb                  1
# tr                  1
# is                  1
# xx                  1
# te                  1
# el                  1

# %%
contagem_da_lingua = tmdb.original_language.value_counts().to_frame().reset_index()
contagem_da_lingua.columns = ['original_language', 'total']
contagem_da_lingua.head()
# Out:
#   original_language  total
# 0                en   4505
# 1                fr     70
# 2                es     32
# 3                zh     27
# 4                de     27

# %%
import seaborn as sns

# %%
sns.barplot(x='original_language', y='total', data=contagem_da_lingua)
# Out:
# <AxesSubplot:xlabel='original_language', ylabel='total'>

# %%
sns.catplot(x="original_language", kind="count", data=tmdb)

# %%
import matplotlib.pyplot as plt
plt.pie(contagem_da_lingua['total'], labels = contagem_da_lingua)
# Out:
# ([<matplotlib.patches.Wedge at 0x299c4fd6640>,
# ...
#  [Text(-1.0791697536499925, 0.2130554923183512, 'original_language'),
#   Text(1.0355355017029462, -0.3710339940124459, 'total')])

# %%
total_por_lingua = tmdb['original_language'].value_counts()
total_por_lingua.loc['en']
# Out:
# 4505

# %%
total_geral = total_por_lingua.sum()
total_de_ingles = total_por_lingua.loc['en']
total_do_resto = total_geral - total_de_ingles
print(total_de_ingles, total_do_resto)
# Out:
# 4505 298

# %%
dados = {
    'lingua':['ingles', 'outros'],
    'total':[total_de_ingles, total_do_resto]
}
dados = pd.DataFrame(dados)
dados
# Out:
#    lingua  total
# 0  ingles   4505
# 1  outros    298

# %%
sns.barplot(data = dados, x = 'lingua', y = 'total')
# Out:
# <AxesSubplot:xlabel='lingua', ylabel='total'>

# %%
plt.pie(dados['total'], labels = dados['lingua'])
# Out:
# ([<matplotlib.patches.Wedge at 0x299c5084c40>,
# ...
#  [Text(-1.0791697536499925, 0.2130554923183512, 'ingles'),
#   Text(1.0791697511565306, -0.2130555049482467, 'outros')])

# %%
tmdb.query("original_language == 'en'")
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4797          0  [{"id": 10769, "name": "Foreign"}, {"id": 53, ...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
filmes_sem_lingua_original_em_ingles = tmdb.query("original_language != 'en'")

# %%
total_por_lingua_de_outros_filmes = tmdb.query("original_language != 'en'").original_language.value_counts()

# %%
sns.catplot(x = 'original_language', data = filmes_sem_lingua_original_em_ingles, 
            kind = 'count', 
            aspect = 2,
            palette = 'GnBu_d',
            order = total_por_lingua_de_outros_filmes.index)
